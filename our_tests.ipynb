# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import PIL
from PIL import Image
import os
import csv
import matplotlib.pyplot as plt
import random
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras import models
from keras import layers
from keras.models import load_model
from tensorflow.keras.applications import ResNet50
from keras.preprocessing.image import ImageDataGenerator

# %%
model = load_model('ResNet_model2.h5')

# %%
labels = {
    0:"A",1:"Agol",2:"Amin",3:"B",4:"Beskonechnost",5:"C",6:"CH",7:"Centar",8:"Cvekje",9:"D",10:"DJ",
    11:"DZ",12:"Delenje",13:"Dopir",14:"E",15:"F",16:"Fizika",17:"G",18:"H",19:"I",20:"Jas",21:"Javanje",22:"K",
    23:"Kolache",24:"Korona",25:"Krst",26:"Kukja",27:"L",28:"LJ",29:"M",30:"Mnogu",31:"N",32:"NJ",33:"O",34:"P",
    35:"Peperutka",36:"Pritisok",37:"Prst",38:"R",39:"Rob",40:"S",41:"SH",42:"Sever",43:"Sida",44:"Sin",45:"Svekja",
    46:"T",47:"Telefon",48:"TojTaaToa",49:"U",50:"V",51:"Valkano",52:"Vilushka",53:"Z",54:"ZH",55:"Zamenki",56:"Zholtica",57:"Zoshto"
}

# %%
test = pd.read_csv("test.csv")

# %%
test_labels = test['target']

# %%
test_labels_new = np_utils.to_categorical(test_labels)

# %%
test_paths = test['image_path']

# %%
test['target'] = test['target'].apply(str)

# %%
test_datagen = ImageDataGenerator()

# %%
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='image_path',
    y_col='target',
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',shuffle=False)
# Out:
# Found 69 validated image filenames belonging to 58 classes.

# %%
loss,test_accuracy = model.evaluate_generator(test_generator)
print("Test accuracy:",test_accuracy)
# Out:
# C:\Users\Tiana\AppData\Local\Temp\ipykernel_7344\286399432.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss,test_accuracy = model.evaluate_generator(test_generator)
# Test accuracy: 0.95652174949646

# %%
files=test_generator.filenames
class_dict=test_generator.class_indices 
rev_dict={}
for key, value in class_dict.items():
    rev_dict[value]=key

# %%
predictions = model.predict(test_generator)
# Out:
# 2/2 [==============================] - 33s 2s/step

# %%
image1 = Image.open(test_generator.filenames[58]).resize((224,224))
image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image1 = np.array(image1)

# %%
image1 = image1.reshape(1,224,224,3)

# %%
predictions1 = model.predict(image1)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
for i, p in enumerate(predictions1):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is C with index 5.0

# %%
image2 = Image.open(test_generator.filenames[59]).resize((224,224))
image2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image2 = np.array(image2)

# %%
image2 = image2.reshape(1,224,224,3)

# %%
predictions2 = model.predict(image2)
# Out:
# 1/1 [==============================] - 0s 494ms/step

# %%
for i, p in enumerate(predictions2):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is T with index 46.0

# %%
image3 = Image.open(test_generator.filenames[60]).resize((224,224))
image3
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image3 = np.array(image3)

# %%
image3 = image3.reshape(1,224,224,3)

# %%
predictions3 = model.predict(image3)
# Out:
# 1/1 [==============================] - 1s 545ms/step

# %%
for i, p in enumerate(predictions3):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is B with index 3.0

# %%
image4 = Image.open(test_generator.filenames[61]).resize((224,224))
image4
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image4 = np.array(image4)

# %%
image4 = image4.reshape(1,224,224,3)

# %%
predictions4 = model.predict(image4)
# Out:
# 1/1 [==============================] - 1s 646ms/step

# %%
for i, p in enumerate(predictions4):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is N with index 31.0

# %%
image5 = Image.open(test_generator.filenames[62]).resize((224,224))
image5
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image5 = np.array(image5)

# %%
image5 = image5.reshape(1,224,224,3)

# %%
predictions5 = model.predict(image5)
# Out:
# 1/1 [==============================] - 1s 505ms/step

# %%
for i, p in enumerate(predictions5):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is N with index 31.0

# %%
image6 = Image.open(test_generator.filenames[63]).resize((224,224))
image6
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image6 = np.array(image6)

# %%
image6 = image6.reshape(1,224,224,3)

# %%
predictions6 = model.predict(image6)
# Out:
# 1/1 [==============================] - 0s 434ms/step

# %%
for i, p in enumerate(predictions6):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is Centar with index 7.0

# %%
image7 = Image.open(test_generator.filenames[64]).resize((224,224))
image7
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image7 = np.array(image7)

# %%
image7 = image7.reshape(1,224,224,3)

# %%
predictions7 = model.predict(image7)
# Out:
# 1/1 [==============================] - 0s 424ms/step

# %%
for i, p in enumerate(predictions7):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is Korona with index 24.0

# %%
image8 = Image.open(test_generator.filenames[65]).resize((224,224))
image8
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image8 = np.array(image8)

# %%
image8 = image8.reshape(1,224,224,3)

# %%
predictions8 = model.predict(image8)
# Out:
# 1/1 [==============================] - 0s 423ms/step

# %%
for i, p in enumerate(predictions8):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is Fizika with index 16.0

# %%
image9 = Image.open(test_generator.filenames[66]).resize((224,224))
image9
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image9 = np.array(image9)

# %%
image9 = image9.reshape(1,224,224,3)

# %%
predictions9 = model.predict(image9)
# Out:
# 1/1 [==============================] - 1s 660ms/step

# %%
for i, p in enumerate(predictions9):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is Fizika with index 16.0

# %%
image10 = Image.open(test_generator.filenames[67]).resize((224,224))
image10
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image10 = np.array(image10)

# %%
image10 = image10.reshape(1,224,224,3)

# %%
predictions10 = model.predict(image10)
# Out:
# 1/1 [==============================] - 1s 990ms/step

# %%
for i, p in enumerate(predictions10):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is Peperutka with index 35.0

# %%
image11 = Image.open(test_generator.filenames[68]).resize((224,224))
image11
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image11 = np.array(image11)

# %%
image11 = image11.reshape(1,224,224,3)

# %%
predictions11 = model.predict(image11)
# Out:
# 1/1 [==============================] - 1s 946ms/step

# %%
for i, p in enumerate(predictions11):
    index=np.argmax(p)
    class_=rev_dict[index]
    num = int(float(class_))
    print('Predicted class is',labels[num],'with index',class_)
# Out:
# Predicted class is ZH with index 54.0
